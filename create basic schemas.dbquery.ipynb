-- %%
-- Criar catálogo
CREATE CATALOG IF NOT EXISTS desafio_grupo1;

-- Criar schemas
CREATE SCHEMA IF NOT EXISTS desafio_grupo1.bronze;
CREATE SCHEMA IF NOT EXISTS desafio_grupo1.gold;
CREATE SCHEMA IF NOT EXISTS desafio_grupo1.landing;
CREATE SCHEMA IF NOT EXISTS desafio_grupo1.silver;

-- Criar volumes no schema landing
CREATE VOLUME IF NOT EXISTS desafio_grupo1.landing.files;
CREATE VOLUME IF NOT EXISTS desafio_grupo1.landing.metadata;
